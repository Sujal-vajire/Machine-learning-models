# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujal-vajire/Machine-learning-models/blob/main/RNN_LSTM_100Epoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('dataset1.csv',)

# %%
data_sun = data[['UNIXTime','Radiation']].iloc[:31000,:]
data_sun.set_index('UNIXTime',drop=True,inplace=True)

# %%
MMS = MinMaxScaler()
data_sun[data_sun.columns] = MMS.fit_transform(data_sun)

# %%
training_size = round(len(data_sun) * 0.80)
train_data = data_sun[:training_size]
test_data  = data_sun[training_size:]

# %%
def create_sequence(dataset,sequence_len):
  sequences = []
  labels = []
  start_idx = 0
  for stop_idx in range(sequence_len,len(dataset)): 
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
X_train, y_train = create_sequence(train_data,100)
X_val, y_val = create_sequence(test_data,100)

# %%
model = Sequential()
model.add(LSTM(units = 64, return_sequences=True, input_shape = (X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.1)) 
model.add(LSTM(units = 32))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
history = model.fit(X_train, y_train, epochs = 100, validation_data = (X_val, y_val), verbose = 1)
# Out:
# Epoch 1/100
# 772/772 [==============================] - 88s 108ms/step - loss: 0.0040 - mean_absolute_error: 0.0323 - val_loss: 0.0020 - val_mean_absolute_error: 0.0246
# Epoch 2/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0032 - mean_absolute_error: 0.0272 - val_loss: 0.0016 - val_mean_absolute_error: 0.0194
# Epoch 3/100
# 772/772 [==============================] - 81s 105ms/step - loss: 0.0031 - mean_absolute_error: 0.0259 - val_loss: 0.0015 - val_mean_absolute_error: 0.0171
# Epoch 4/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0030 - mean_absolute_error: 0.0251 - val_loss: 0.0015 - val_mean_absolute_error: 0.0165
# Epoch 5/100
# 772/772 [==============================] - 85s 110ms/step - loss: 0.0029 - mean_absolute_error: 0.0243 - val_loss: 0.0015 - val_mean_absolute_error: 0.0159
# Epoch 6/100
# 772/772 [==============================] - 83s 107ms/step - loss: 0.0029 - mean_absolute_error: 0.0243 - val_loss: 0.0018 - val_mean_absolute_error: 0.0250
# Epoch 7/100
# 772/772 [==============================] - 83s 107ms/step - loss: 0.0029 - mean_absolute_error: 0.0242 - val_loss: 0.0016 - val_mean_absolute_error: 0.0221
# Epoch 8/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0028 - mean_absolute_error: 0.0240 - val_loss: 0.0014 - val_mean_absolute_error: 0.0150
# Epoch 9/100
# 772/772 [==============================] - 84s 108ms/step - loss: 0.0028 - mean_absolute_error: 0.0236 - val_loss: 0.0014 - val_mean_absolute_error: 0.0143
# Epoch 10/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0028 - mean_absolute_error: 0.0241 - val_loss: 0.0016 - val_mean_absolute_error: 0.0180
# Epoch 11/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0028 - mean_absolute_error: 0.0234 - val_loss: 0.0014 - val_mean_absolute_error: 0.0154
# Epoch 12/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0028 - mean_absolute_error: 0.0233 - val_loss: 0.0016 - val_mean_absolute_error: 0.0188
# Epoch 13/100
# 772/772 [==============================] - 85s 109ms/step - loss: 0.0028 - mean_absolute_error: 0.0235 - val_loss: 0.0015 - val_mean_absolute_error: 0.0154
# Epoch 14/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0028 - mean_absolute_error: 0.0231 - val_loss: 0.0015 - val_mean_absolute_error: 0.0159
# Epoch 15/100
# 772/772 [==============================] - 83s 108ms/step - loss: 0.0028 - mean_absolute_error: 0.0231 - val_loss: 0.0015 - val_mean_absolute_error: 0.0155
# Epoch 16/100
# 772/772 [==============================] - 83s 107ms/step - loss: 0.0027 - mean_absolute_error: 0.0229 - val_loss: 0.0015 - val_mean_absolute_error: 0.0159
# Epoch 17/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0028 - mean_absolute_error: 0.0229 - val_loss: 0.0016 - val_mean_absolute_error: 0.0219
# Epoch 18/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0027 - mean_absolute_error: 0.0229 - val_loss: 0.0015 - val_mean_absolute_error: 0.0191
# Epoch 19/100
# 772/772 [==============================] - 86s 112ms/step - loss: 0.0028 - mean_absolute_error: 0.0227 - val_loss: 0.0014 - val_mean_absolute_error: 0.0165
# Epoch 20/100
# 772/772 [==============================] - 85s 110ms/step - loss: 0.0027 - mean_absolute_error: 0.0225 - val_loss: 0.0014 - val_mean_absolute_error: 0.0152
# Epoch 21/100
# 772/772 [==============================] - 83s 108ms/step - loss: 0.0027 - mean_absolute_error: 0.0224 - val_loss: 0.0014 - val_mean_absolute_error: 0.0135
# Epoch 22/100
# 772/772 [==============================] - 105s 136ms/step - loss: 0.0027 - mean_absolute_error: 0.0230 - val_loss: 0.0017 - val_mean_absolute_error: 0.0203
# Epoch 23/100
# 772/772 [==============================] - 84s 108ms/step - loss: 0.0027 - mean_absolute_error: 0.0228 - val_loss: 0.0014 - val_mean_absolute_error: 0.0160
# Epoch 24/100
# 772/772 [==============================] - 83s 107ms/step - loss: 0.0027 - mean_absolute_error: 0.0228 - val_loss: 0.0014 - val_mean_absolute_error: 0.0143
# Epoch 25/100
# 772/772 [==============================] - 84s 108ms/step - loss: 0.0027 - mean_absolute_error: 0.0226 - val_loss: 0.0015 - val_mean_absolute_error: 0.0167
# Epoch 26/100
# 772/772 [==============================] - 87s 113ms/step - loss: 0.0027 - mean_absolute_error: 0.0224 - val_loss: 0.0014 - val_mean_absolute_error: 0.0140
# Epoch 27/100
# 772/772 [==============================] - 85s 110ms/step - loss: 0.0027 - mean_absolute_error: 0.0223 - val_loss: 0.0016 - val_mean_absolute_error: 0.0183
# Epoch 28/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0027 - mean_absolute_error: 0.0222 - val_loss: 0.0016 - val_mean_absolute_error: 0.0195
# Epoch 29/100
# 772/772 [==============================] - 83s 108ms/step - loss: 0.0027 - mean_absolute_error: 0.0224 - val_loss: 0.0014 - val_mean_absolute_error: 0.0152
# Epoch 30/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0027 - mean_absolute_error: 0.0224 - val_loss: 0.0014 - val_mean_absolute_error: 0.0161
# Epoch 31/100
# 772/772 [==============================] - 82s 107ms/step - loss: 0.0027 - mean_absolute_error: 0.0225 - val_loss: 0.0014 - val_mean_absolute_error: 0.0164
# Epoch 32/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0014 - val_mean_absolute_error: 0.0158
# Epoch 33/100
# 772/772 [==============================] - 82s 107ms/step - loss: 0.0027 - mean_absolute_error: 0.0223 - val_loss: 0.0014 - val_mean_absolute_error: 0.0157
# Epoch 34/100
# 772/772 [==============================] - 81s 106ms/step - loss: 0.0027 - mean_absolute_error: 0.0219 - val_loss: 0.0014 - val_mean_absolute_error: 0.0155
# Epoch 35/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0014 - val_mean_absolute_error: 0.0168
# Epoch 36/100
# 772/772 [==============================] - 81s 105ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0016 - val_mean_absolute_error: 0.0177
# Epoch 37/100
# 772/772 [==============================] - 82s 107ms/step - loss: 0.0027 - mean_absolute_error: 0.0224 - val_loss: 0.0016 - val_mean_absolute_error: 0.0196
# Epoch 38/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0027 - mean_absolute_error: 0.0222 - val_loss: 0.0015 - val_mean_absolute_error: 0.0177
# Epoch 39/100
# 772/772 [==============================] - 83s 108ms/step - loss: 0.0027 - mean_absolute_error: 0.0223 - val_loss: 0.0014 - val_mean_absolute_error: 0.0160
# Epoch 40/100
# 772/772 [==============================] - 83s 107ms/step - loss: 0.0027 - mean_absolute_error: 0.0218 - val_loss: 0.0015 - val_mean_absolute_error: 0.0159
# Epoch 41/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0027 - mean_absolute_error: 0.0219 - val_loss: 0.0015 - val_mean_absolute_error: 0.0147
# Epoch 42/100
# 772/772 [==============================] - 82s 106ms/step - loss: 0.0028 - mean_absolute_error: 0.0248 - val_loss: 0.0014 - val_mean_absolute_error: 0.0154
# Epoch 43/100
# 772/772 [==============================] - 83s 107ms/step - loss: 0.0028 - mean_absolute_error: 0.0234 - val_loss: 0.0016 - val_mean_absolute_error: 0.0225
# Epoch 44/100
# 772/772 [==============================] - 82s 107ms/step - loss: 0.0028 - mean_absolute_error: 0.0235 - val_loss: 0.0014 - val_mean_absolute_error: 0.0155
# Epoch 45/100
# 772/772 [==============================] - 85s 109ms/step - loss: 0.0028 - mean_absolute_error: 0.0230 - val_loss: 0.0015 - val_mean_absolute_error: 0.0167
# Epoch 46/100
# 772/772 [==============================] - 85s 110ms/step - loss: 0.0027 - mean_absolute_error: 0.0223 - val_loss: 0.0015 - val_mean_absolute_error: 0.0161
# Epoch 47/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0027 - mean_absolute_error: 0.0224 - val_loss: 0.0015 - val_mean_absolute_error: 0.0169
# Epoch 48/100
# 772/772 [==============================] - 84s 108ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0014 - val_mean_absolute_error: 0.0147
# Epoch 49/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0027 - mean_absolute_error: 0.0222 - val_loss: 0.0015 - val_mean_absolute_error: 0.0163
# Epoch 50/100
# 772/772 [==============================] - 83s 108ms/step - loss: 0.0027 - mean_absolute_error: 0.0219 - val_loss: 0.0015 - val_mean_absolute_error: 0.0175
# Epoch 51/100
# 772/772 [==============================] - 85s 111ms/step - loss: 0.0027 - mean_absolute_error: 0.0222 - val_loss: 0.0015 - val_mean_absolute_error: 0.0151
# Epoch 52/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0014 - val_mean_absolute_error: 0.0164
# Epoch 53/100
# 772/772 [==============================] - 84s 109ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0014 - val_mean_absolute_error: 0.0161
# Epoch 54/100
# 772/772 [==============================] - 85s 111ms/step - loss: 0.0027 - mean_absolute_error: 0.0217 - val_loss: 0.0014 - val_mean_absolute_error: 0.0177
# Epoch 55/100
# 772/772 [==============================] - 86s 111ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0015 - val_mean_absolute_error: 0.0176
# Epoch 56/100
# 772/772 [==============================] - 90s 116ms/step - loss: 0.0027 - mean_absolute_error: 0.0219 - val_loss: 0.0015 - val_mean_absolute_error: 0.0164
# Epoch 57/100
# 772/772 [==============================] - 89s 116ms/step - loss: 0.0027 - mean_absolute_error: 0.0218 - val_loss: 0.0014 - val_mean_absolute_error: 0.0154
# Epoch 58/100
# 772/772 [==============================] - 90s 117ms/step - loss: 0.0027 - mean_absolute_error: 0.0219 - val_loss: 0.0014 - val_mean_absolute_error: 0.0157
# Epoch 59/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0027 - mean_absolute_error: 0.0218 - val_loss: 0.0014 - val_mean_absolute_error: 0.0137
# Epoch 60/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0027 - mean_absolute_error: 0.0216 - val_loss: 0.0015 - val_mean_absolute_error: 0.0164
# Epoch 61/100
# 772/772 [==============================] - 90s 117ms/step - loss: 0.0026 - mean_absolute_error: 0.0216 - val_loss: 0.0014 - val_mean_absolute_error: 0.0155
# Epoch 62/100
# 772/772 [==============================] - 90s 117ms/step - loss: 0.0027 - mean_absolute_error: 0.0219 - val_loss: 0.0016 - val_mean_absolute_error: 0.0166
# Epoch 63/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0026 - mean_absolute_error: 0.0214 - val_loss: 0.0016 - val_mean_absolute_error: 0.0175
# Epoch 64/100
# 772/772 [==============================] - 89s 116ms/step - loss: 0.0026 - mean_absolute_error: 0.0216 - val_loss: 0.0015 - val_mean_absolute_error: 0.0172
# Epoch 65/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0027 - mean_absolute_error: 0.0216 - val_loss: 0.0014 - val_mean_absolute_error: 0.0160
# Epoch 66/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0026 - mean_absolute_error: 0.0216 - val_loss: 0.0015 - val_mean_absolute_error: 0.0175
# Epoch 67/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0026 - mean_absolute_error: 0.0215 - val_loss: 0.0014 - val_mean_absolute_error: 0.0148
# Epoch 68/100
# 772/772 [==============================] - 91s 117ms/step - loss: 0.0026 - mean_absolute_error: 0.0214 - val_loss: 0.0014 - val_mean_absolute_error: 0.0154
# Epoch 69/100
# 772/772 [==============================] - 89s 116ms/step - loss: 0.0026 - mean_absolute_error: 0.0214 - val_loss: 0.0014 - val_mean_absolute_error: 0.0148
# Epoch 70/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0026 - mean_absolute_error: 0.0215 - val_loss: 0.0014 - val_mean_absolute_error: 0.0144
# Epoch 71/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0026 - mean_absolute_error: 0.0214 - val_loss: 0.0014 - val_mean_absolute_error: 0.0150
# Epoch 72/100
# 772/772 [==============================] - 90s 116ms/step - loss: 0.0026 - mean_absolute_error: 0.0213 - val_loss: 0.0014 - val_mean_absolute_error: 0.0146
# Epoch 73/100
# 772/772 [==============================] - 93s 121ms/step - loss: 0.0026 - mean_absolute_error: 0.0212 - val_loss: 0.0014 - val_mean_absolute_error: 0.0172
# Epoch 74/100
# 772/772 [==============================] - 90s 117ms/step - loss: 0.0026 - mean_absolute_error: 0.0215 - val_loss: 0.0014 - val_mean_absolute_error: 0.0142
# Epoch 75/100
# 772/772 [==============================] - 91s 118ms/step - loss: 0.0026 - mean_absolute_error: 0.0213 - val_loss: 0.0014 - val_mean_absolute_error: 0.0155
# Epoch 76/100
# 772/772 [==============================] - 90s 117ms/step - loss: 0.0026 - mean_absolute_error: 0.0212 - val_loss: 0.0014 - val_mean_absolute_error: 0.0143
# Epoch 77/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0026 - mean_absolute_error: 0.0214 - val_loss: 0.0015 - val_mean_absolute_error: 0.0176
# Epoch 78/100
# 772/772 [==============================] - 88s 114ms/step - loss: 0.0026 - mean_absolute_error: 0.0210 - val_loss: 0.0014 - val_mean_absolute_error: 0.0159
# Epoch 79/100
# 772/772 [==============================] - 91s 117ms/step - loss: 0.0026 - mean_absolute_error: 0.0214 - val_loss: 0.0015 - val_mean_absolute_error: 0.0148
# Epoch 80/100
# 772/772 [==============================] - 90s 117ms/step - loss: 0.0026 - mean_absolute_error: 0.0211 - val_loss: 0.0015 - val_mean_absolute_error: 0.0140
# Epoch 81/100
# 772/772 [==============================] - 91s 117ms/step - loss: 0.0026 - mean_absolute_error: 0.0213 - val_loss: 0.0015 - val_mean_absolute_error: 0.0179
# Epoch 82/100
# 772/772 [==============================] - 90s 116ms/step - loss: 0.0026 - mean_absolute_error: 0.0213 - val_loss: 0.0014 - val_mean_absolute_error: 0.0149
# Epoch 83/100
# 772/772 [==============================] - 88s 114ms/step - loss: 0.0026 - mean_absolute_error: 0.0210 - val_loss: 0.0014 - val_mean_absolute_error: 0.0141
# Epoch 84/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0026 - mean_absolute_error: 0.0211 - val_loss: 0.0014 - val_mean_absolute_error: 0.0143
# Epoch 85/100
# 772/772 [==============================] - 89s 116ms/step - loss: 0.0026 - mean_absolute_error: 0.0210 - val_loss: 0.0014 - val_mean_absolute_error: 0.0151
# Epoch 86/100
# 772/772 [==============================] - 89s 115ms/step - loss: 0.0026 - mean_absolute_error: 0.0211 - val_loss: 0.0015 - val_mean_absolute_error: 0.0194
# Epoch 87/100
# 772/772 [==============================] - 87s 112ms/step - loss: 0.0025 - mean_absolute_error: 0.0210 - val_loss: 0.0015 - val_mean_absolute_error: 0.0144
# Epoch 88/100
# 772/772 [==============================] - 90s 117ms/step - loss: 0.0025 - mean_absolute_error: 0.0210 - val_loss: 0.0015 - val_mean_absolute_error: 0.0158
# Epoch 89/100
# 772/772 [==============================] - 87s 113ms/step - loss: 0.0026 - mean_absolute_error: 0.0211 - val_loss: 0.0014 - val_mean_absolute_error: 0.0164
# Epoch 90/100
# 772/772 [==============================] - 90s 116ms/step - loss: 0.0025 - mean_absolute_error: 0.0210 - val_loss: 0.0014 - val_mean_absolute_error: 0.0146
# Epoch 91/100
# 772/772 [==============================] - 91s 118ms/step - loss: 0.0025 - mean_absolute_error: 0.0210 - val_loss: 0.0015 - val_mean_absolute_error: 0.0175
# Epoch 92/100
# 772/772 [==============================] - 89s 116ms/step - loss: 0.0026 - mean_absolute_error: 0.0216 - val_loss: 0.0014 - val_mean_absolute_error: 0.0131
# Epoch 93/100
# 772/772 [==============================] - 88s 114ms/step - loss: 0.0025 - mean_absolute_error: 0.0208 - val_loss: 0.0014 - val_mean_absolute_error: 0.0177
# Epoch 94/100
# 772/772 [==============================] - 93s 121ms/step - loss: 0.0026 - mean_absolute_error: 0.0208 - val_loss: 0.0014 - val_mean_absolute_error: 0.0136
# Epoch 95/100
# 772/772 [==============================] - 87s 113ms/step - loss: 0.0025 - mean_absolute_error: 0.0207 - val_loss: 0.0014 - val_mean_absolute_error: 0.0152
# Epoch 96/100
# 772/772 [==============================] - 87s 113ms/step - loss: 0.0025 - mean_absolute_error: 0.0207 - val_loss: 0.0014 - val_mean_absolute_error: 0.0148
# Epoch 97/100
# 772/772 [==============================] - 87s 112ms/step - loss: 0.0025 - mean_absolute_error: 0.0208 - val_loss: 0.0014 - val_mean_absolute_error: 0.0140
# Epoch 98/100
# 772/772 [==============================] - 87s 113ms/step - loss: 0.0025 - mean_absolute_error: 0.0208 - val_loss: 0.0014 - val_mean_absolute_error: 0.0146
# Epoch 99/100
# 772/772 [==============================] - 87s 113ms/step - loss: 0.0025 - mean_absolute_error: 0.0207 - val_loss: 0.0014 - val_mean_absolute_error: 0.0169
# Epoch 100/100
# 772/772 [==============================] - 86s 112ms/step - loss: 0.0025 - mean_absolute_error: 0.0207 - val_loss: 0.0015 - val_mean_absolute_error: 0.0155

# %%
test_predicted = model.predict(X_val)

fig=plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(test_predicted,label='Radiation, predicted')
plt.plot(y_val,label="Radiation")
plt.title('Prediction on the global sample')
plt.legend()

# %%
error = history.history['mean_absolute_error']
val_error = history.history['val_mean_absolute_error']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(val_error)+1)
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, error, label='Training error')
plt.plot(epochs_range, val_error, label='Validation error')
plt.legend(loc='lower right')
plt.xlim(1, len(val_error)+1)
plt.title('Training and Validation error')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.xlim(1, len(val_error)+1)
plt.title('Training and Validation Loss')
plt.show()

# %%
fig=plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(np.arange(3100,3700),test_predicted[3100:3700],label='Radiation, predicted')
plt.plot(np.arange(3100,3700),y_val[3100:3700],label="Radiation")
plt.legend()

# %%
from sklearn import metrics
score = metrics.mean_squared_error(y_val,test_predicted)
print("Final score (MSE): {}".format(score))
# Out:
# Final score (MSE): 0.0014866433427952774

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_val,test_predicted)
print("Final score (MAE): {}".format(MAE))
# Out:
# Final score (MAE): 0.01545383957402794

# %%
import numpy as np

# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(test_predicted,y_val))
print("Final score (RMSE): {}".format(score))
# Out:
# Final score (RMSE): 0.038557014184130975

# %%
from sklearn.metrics import r2_score
R2 = r2_score(y_val, test_predicted, multioutput='variance_weighted')
print("Final score (R2): {}".format(R2))
# Out:
# Final score (R2): 0.9476844127116596

# %%
import pandas as pd
from scipy.stats import skew
from scipy.stats import kurtosis

print("Final score (skew):")
print(skew(test_predicted, axis=0, bias=True))
# Out:
# Final score (skew):
# [1.4280171]

# %%
print("Final score (kurtosis):")
print(kurtosis(test_predicted, axis=0, bias=True))
# Out:
# Final score (kurtosis):
# [0.6208563]
