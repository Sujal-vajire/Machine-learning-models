# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujal-vajire/Machine-learning-models/blob/main/RNN_LSTM_50Epoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('dataset1.csv',)

# %%
data_sun = data[['UNIXTime','Radiation']].iloc[:31000,:]
data_sun.set_index('UNIXTime',drop=True,inplace=True)

# %%
MMS = MinMaxScaler()
data_sun[data_sun.columns] = MMS.fit_transform(data_sun)

# %%
training_size = round(len(data_sun) * 0.80)
train_data = data_sun[:training_size]
test_data  = data_sun[training_size:]

# %%
def create_sequence(dataset,sequence_len):
  sequences = []
  labels = []
  start_idx = 0
  for stop_idx in range(sequence_len,len(dataset)): 
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
X_train, y_train = create_sequence(train_data,100)
X_val, y_val = create_sequence(test_data,100)

# %%
model = Sequential()
model.add(LSTM(units = 64, return_sequences=True, input_shape = (X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.1)) 
model.add(LSTM(units = 32))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
history = model.fit(X_train, y_train, epochs = 50, validation_data = (X_val, y_val), verbose = 1)
# Out:
# Epoch 1/50
# 772/772 [==============================] - 82s 102ms/step - loss: 0.0040 - mean_absolute_error: 0.0317 - val_loss: 0.0017 - val_mean_absolute_error: 0.0180
# Epoch 2/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0031 - mean_absolute_error: 0.0268 - val_loss: 0.0016 - val_mean_absolute_error: 0.0212
# Epoch 3/50
# 772/772 [==============================] - 72s 94ms/step - loss: 0.0030 - mean_absolute_error: 0.0250 - val_loss: 0.0016 - val_mean_absolute_error: 0.0223
# Epoch 4/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0029 - mean_absolute_error: 0.0249 - val_loss: 0.0014 - val_mean_absolute_error: 0.0140
# Epoch 5/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0029 - mean_absolute_error: 0.0243 - val_loss: 0.0015 - val_mean_absolute_error: 0.0174
# Epoch 6/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0029 - mean_absolute_error: 0.0241 - val_loss: 0.0014 - val_mean_absolute_error: 0.0148
# Epoch 7/50
# 772/772 [==============================] - 73s 94ms/step - loss: 0.0029 - mean_absolute_error: 0.0244 - val_loss: 0.0014 - val_mean_absolute_error: 0.0175
# Epoch 8/50
# 772/772 [==============================] - 71s 93ms/step - loss: 0.0028 - mean_absolute_error: 0.0236 - val_loss: 0.0014 - val_mean_absolute_error: 0.0150
# Epoch 9/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0028 - mean_absolute_error: 0.0235 - val_loss: 0.0014 - val_mean_absolute_error: 0.0170
# Epoch 10/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0028 - mean_absolute_error: 0.0236 - val_loss: 0.0014 - val_mean_absolute_error: 0.0149
# Epoch 11/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0028 - mean_absolute_error: 0.0238 - val_loss: 0.0014 - val_mean_absolute_error: 0.0175
# Epoch 12/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0028 - mean_absolute_error: 0.0230 - val_loss: 0.0014 - val_mean_absolute_error: 0.0161
# Epoch 13/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0028 - mean_absolute_error: 0.0230 - val_loss: 0.0015 - val_mean_absolute_error: 0.0201
# Epoch 14/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0028 - mean_absolute_error: 0.0229 - val_loss: 0.0014 - val_mean_absolute_error: 0.0156
# Epoch 15/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0028 - mean_absolute_error: 0.0231 - val_loss: 0.0016 - val_mean_absolute_error: 0.0176
# Epoch 16/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0028 - mean_absolute_error: 0.0234 - val_loss: 0.0015 - val_mean_absolute_error: 0.0169
# Epoch 17/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0028 - mean_absolute_error: 0.0232 - val_loss: 0.0014 - val_mean_absolute_error: 0.0156
# Epoch 18/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0028 - mean_absolute_error: 0.0230 - val_loss: 0.0014 - val_mean_absolute_error: 0.0136
# Epoch 19/50
# 772/772 [==============================] - 72s 94ms/step - loss: 0.0028 - mean_absolute_error: 0.0226 - val_loss: 0.0014 - val_mean_absolute_error: 0.0155
# Epoch 20/50
# 772/772 [==============================] - 73s 95ms/step - loss: 0.0027 - mean_absolute_error: 0.0227 - val_loss: 0.0014 - val_mean_absolute_error: 0.0154
# Epoch 21/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0227 - val_loss: 0.0015 - val_mean_absolute_error: 0.0171
# Epoch 22/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0028 - mean_absolute_error: 0.0230 - val_loss: 0.0014 - val_mean_absolute_error: 0.0145
# Epoch 23/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0028 - mean_absolute_error: 0.0227 - val_loss: 0.0015 - val_mean_absolute_error: 0.0175
# Epoch 24/50
# 772/772 [==============================] - 73s 94ms/step - loss: 0.0027 - mean_absolute_error: 0.0223 - val_loss: 0.0015 - val_mean_absolute_error: 0.0163
# Epoch 25/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0027 - mean_absolute_error: 0.0224 - val_loss: 0.0015 - val_mean_absolute_error: 0.0151
# Epoch 26/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0221 - val_loss: 0.0014 - val_mean_absolute_error: 0.0153
# Epoch 27/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0225 - val_loss: 0.0015 - val_mean_absolute_error: 0.0187
# Epoch 28/50
# 772/772 [==============================] - 74s 96ms/step - loss: 0.0027 - mean_absolute_error: 0.0225 - val_loss: 0.0014 - val_mean_absolute_error: 0.0165
# Epoch 29/50
# 772/772 [==============================] - 73s 95ms/step - loss: 0.0027 - mean_absolute_error: 0.0226 - val_loss: 0.0014 - val_mean_absolute_error: 0.0141
# Epoch 30/50
# 772/772 [==============================] - 72s 94ms/step - loss: 0.0027 - mean_absolute_error: 0.0221 - val_loss: 0.0014 - val_mean_absolute_error: 0.0147
# Epoch 31/50
# 772/772 [==============================] - 73s 95ms/step - loss: 0.0027 - mean_absolute_error: 0.0221 - val_loss: 0.0015 - val_mean_absolute_error: 0.0150
# Epoch 32/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0223 - val_loss: 0.0014 - val_mean_absolute_error: 0.0149
# Epoch 33/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0225 - val_loss: 0.0014 - val_mean_absolute_error: 0.0155
# Epoch 34/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0015 - val_mean_absolute_error: 0.0156
# Epoch 35/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0027 - mean_absolute_error: 0.0224 - val_loss: 0.0016 - val_mean_absolute_error: 0.0174
# Epoch 36/50
# 772/772 [==============================] - 74s 96ms/step - loss: 0.0028 - mean_absolute_error: 0.0234 - val_loss: 0.0014 - val_mean_absolute_error: 0.0147
# Epoch 37/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0221 - val_loss: 0.0014 - val_mean_absolute_error: 0.0172
# Epoch 38/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0222 - val_loss: 0.0014 - val_mean_absolute_error: 0.0149
# Epoch 39/50
# 772/772 [==============================] - 72s 94ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0014 - val_mean_absolute_error: 0.0160
# Epoch 40/50
# 772/772 [==============================] - 71s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0218 - val_loss: 0.0015 - val_mean_absolute_error: 0.0149
# Epoch 41/50
# 772/772 [==============================] - 71s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0221 - val_loss: 0.0014 - val_mean_absolute_error: 0.0171
# Epoch 42/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0220 - val_loss: 0.0014 - val_mean_absolute_error: 0.0147
# Epoch 43/50
# 772/772 [==============================] - 71s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0221 - val_loss: 0.0014 - val_mean_absolute_error: 0.0158
# Epoch 44/50
# 772/772 [==============================] - 71s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0219 - val_loss: 0.0014 - val_mean_absolute_error: 0.0140
# Epoch 45/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0224 - val_loss: 0.0015 - val_mean_absolute_error: 0.0159
# Epoch 46/50
# 772/772 [==============================] - 72s 94ms/step - loss: 0.0027 - mean_absolute_error: 0.0225 - val_loss: 0.0015 - val_mean_absolute_error: 0.0164
# Epoch 47/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0219 - val_loss: 0.0014 - val_mean_absolute_error: 0.0150
# Epoch 48/50
# 772/772 [==============================] - 72s 93ms/step - loss: 0.0027 - mean_absolute_error: 0.0216 - val_loss: 0.0014 - val_mean_absolute_error: 0.0147
# Epoch 49/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0027 - mean_absolute_error: 0.0219 - val_loss: 0.0014 - val_mean_absolute_error: 0.0158
# Epoch 50/50
# 772/772 [==============================] - 71s 92ms/step - loss: 0.0027 - mean_absolute_error: 0.0221 - val_loss: 0.0015 - val_mean_absolute_error: 0.0171

# %%
test_predicted = model.predict(X_val)

fig=plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(test_predicted,label='Radiation, predicted')
plt.plot(y_val,label="Radiation")
plt.title('Prediction on the global sample')
plt.legend()

# %%
error = history.history['mean_absolute_error']
val_error = history.history['val_mean_absolute_error']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(val_error)+1)
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, error, label='Training error')
plt.plot(epochs_range, val_error, label='Validation error')
plt.legend(loc='lower right')
plt.xlim(1, len(val_error)+1)
plt.title('Training and Validation error')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.xlim(1, len(val_error)+1)
plt.title('Training and Validation Loss')
plt.show()

# %%
fig=plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(np.arange(3100,3700),test_predicted[3100:3700],label='Radiation, predicted')
plt.plot(np.arange(3100,3700),y_val[3100:3700],label="Radiation")
plt.legend()

# %%
from sklearn import metrics
score = metrics.mean_squared_error(y_val,test_predicted)
print("Final score (MSE): {}".format(score))
# Out:
# Final score (MSE): 0.0015471067686881202

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_val,test_predicted)
print("Final score (MAE): {}".format(MAE))
# Out:
# Final score (MAE): 0.01712221541202328

# %%
import numpy as np

# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(test_predicted,y_val))
print("Final score (RMSE): {}".format(score))
# Out:
# Final score (RMSE): 0.039333278133002345

# %%
from sklearn.metrics import r2_score
R2 = r2_score(y_val, test_predicted, multioutput='variance_weighted')
print("Final score (R2): {}".format(R2))
# Out:
# Final score (R2): 0.9455566800242073

# %%
import pandas as pd
from scipy.stats import skew
from scipy.stats import kurtosis

print("Final score (skew):")
print(skew(test_predicted, axis=0, bias=True))
# Out:
# Final score (skew):
# [1.4033628]

# %%
print("Final score (kurtosis):")
print(kurtosis(test_predicted, axis=0, bias=True))
# Out:
# Final score (kurtosis):
# [0.5513494]
