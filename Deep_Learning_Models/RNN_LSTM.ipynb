# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujal-vajire/Machine-learning-models/blob/main/RNN_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('solar.csv',)

# %%
data_sun = data[['UNIXTime','Radiation']].iloc[:31000,:]
data_sun.set_index('UNIXTime',drop=True,inplace=True)

# %%
MMS = MinMaxScaler()
data_sun[data_sun.columns] = MMS.fit_transform(data_sun)

# %%
training_size = round(len(data_sun) * 0.80)
train_data = data_sun[:training_size]
test_data  = data_sun[training_size:]

# %%
def create_sequence(dataset,sequence_len):
  sequences = []
  labels = []
  start_idx = 0
  for stop_idx in range(sequence_len,len(dataset)): 
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
X_train, y_train = create_sequence(train_data,100)
X_val, y_val = create_sequence(test_data,100)

# %%
model = Sequential()
model.add(LSTM(units = 64, return_sequences=True, input_shape = (X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.1)) 
model.add(LSTM(units = 32))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
history = model.fit(X_train, y_train, epochs = 20, validation_data = (X_val, y_val), verbose = 1)
# Out:
# Epoch 1/20
# 772/772 [==============================] - 82s 101ms/step - loss: 0.0040 - mean_absolute_error: 0.0317 - val_loss: 0.0018 - val_mean_absolute_error: 0.0194
# Epoch 2/20
# 772/772 [==============================] - 77s 100ms/step - loss: 0.0032 - mean_absolute_error: 0.0269 - val_loss: 0.0017 - val_mean_absolute_error: 0.0234
# Epoch 3/20
# 772/772 [==============================] - 77s 100ms/step - loss: 0.0030 - mean_absolute_error: 0.0251 - val_loss: 0.0015 - val_mean_absolute_error: 0.0168
# Epoch 4/20
# 772/772 [==============================] - 77s 100ms/step - loss: 0.0030 - mean_absolute_error: 0.0252 - val_loss: 0.0015 - val_mean_absolute_error: 0.0167
# Epoch 5/20
# 772/772 [==============================] - 77s 99ms/step - loss: 0.0029 - mean_absolute_error: 0.0243 - val_loss: 0.0014 - val_mean_absolute_error: 0.0139
# Epoch 6/20
# 772/772 [==============================] - 77s 99ms/step - loss: 0.0029 - mean_absolute_error: 0.0241 - val_loss: 0.0014 - val_mean_absolute_error: 0.0163
# Epoch 7/20
# 772/772 [==============================] - 76s 99ms/step - loss: 0.0029 - mean_absolute_error: 0.0240 - val_loss: 0.0015 - val_mean_absolute_error: 0.0181
# Epoch 8/20
# 772/772 [==============================] - 77s 99ms/step - loss: 0.0028 - mean_absolute_error: 0.0238 - val_loss: 0.0014 - val_mean_absolute_error: 0.0147
# Epoch 9/20
# 772/772 [==============================] - 77s 99ms/step - loss: 0.0028 - mean_absolute_error: 0.0232 - val_loss: 0.0015 - val_mean_absolute_error: 0.0183
# Epoch 10/20
# 772/772 [==============================] - 76s 98ms/step - loss: 0.0028 - mean_absolute_error: 0.0232 - val_loss: 0.0015 - val_mean_absolute_error: 0.0156
# Epoch 11/20
# 772/772 [==============================] - 76s 99ms/step - loss: 0.0028 - mean_absolute_error: 0.0235 - val_loss: 0.0016 - val_mean_absolute_error: 0.0171
# Epoch 12/20
# 772/772 [==============================] - 76s 99ms/step - loss: 0.0028 - mean_absolute_error: 0.0234 - val_loss: 0.0014 - val_mean_absolute_error: 0.0169
# Epoch 13/20
# 772/772 [==============================] - 76s 98ms/step - loss: 0.0028 - mean_absolute_error: 0.0228 - val_loss: 0.0014 - val_mean_absolute_error: 0.0140
# Epoch 14/20
# 772/772 [==============================] - 76s 98ms/step - loss: 0.0028 - mean_absolute_error: 0.0227 - val_loss: 0.0014 - val_mean_absolute_error: 0.0138
# Epoch 15/20
# 772/772 [==============================] - 76s 98ms/step - loss: 0.0028 - mean_absolute_error: 0.0229 - val_loss: 0.0014 - val_mean_absolute_error: 0.0172
# Epoch 16/20
# 772/772 [==============================] - 76s 99ms/step - loss: 0.0027 - mean_absolute_error: 0.0228 - val_loss: 0.0014 - val_mean_absolute_error: 0.0163
# Epoch 17/20
# 772/772 [==============================] - 76s 99ms/step - loss: 0.0028 - mean_absolute_error: 0.0228 - val_loss: 0.0014 - val_mean_absolute_error: 0.0158
# Epoch 18/20
# 772/772 [==============================] - 76s 99ms/step - loss: 0.0027 - mean_absolute_error: 0.0226 - val_loss: 0.0015 - val_mean_absolute_error: 0.0171
# Epoch 19/20
# 772/772 [==============================] - 76s 99ms/step - loss: 0.0027 - mean_absolute_error: 0.0229 - val_loss: 0.0014 - val_mean_absolute_error: 0.0164
# Epoch 20/20
# 772/772 [==============================] - 77s 99ms/step - loss: 0.0027 - mean_absolute_error: 0.0229 - val_loss: 0.0016 - val_mean_absolute_error: 0.0168

# %%
test_predicted = model.predict(X_val)

fig=plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(test_predicted,label='Radiation, predicted')
plt.plot(y_val,label="Radiation")
plt.title('Prediction on the global sample')
plt.legend()

# %%
error = history.history['mean_absolute_error']
val_error = history.history['val_mean_absolute_error']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(val_error)+1)
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, error, label='Training error')
plt.plot(epochs_range, val_error, label='Validation error')
plt.legend(loc='lower right')
plt.xlim(1, len(val_error)+1)
plt.title('Training and Validation error')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.xlim(1, len(val_error)+1)
plt.title('Training and Validation Loss')
plt.show()

# %%
fig=plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(np.arange(3100,3700),test_predicted[3100:3700],label='Radiation, predicted')
plt.plot(np.arange(3100,3700),y_val[3100:3700],label="Radiation")
plt.legend()

# %%
from sklearn import metrics
score = metrics.mean_squared_error(y_val,test_predicted)
print("Final score (MSE): {}".format(score))
# Out:
# Final score (MSE): 0.0015525592635964296

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_val,test_predicted)
print("Final score (MAE): {}".format(MAE))
# Out:
# Final score (MAE): 0.016802466380887972

# %%
import numpy as np

# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(test_predicted,y_val))
print("Final score (RMSE): {}".format(score))
# Out:
# Final score (RMSE): 0.03940252864470033

# %%
from sklearn.metrics import r2_score
R2 = r2_score(y_val, test_predicted, multioutput='variance_weighted')
print("Final score (R2): {}".format(R2))
# Out:
# Final score (R2): 0.9453648044982464

# %%
import pandas as pd
from scipy.stats import skew
from scipy.stats import kurtosis

print("Final score (skew):")
print(skew(test_predicted, axis=0, bias=True))
# Out:
# Final score (skew):
# [1.3861984]

# %%
print("Final score (kurtosis):")
print(kurtosis(test_predicted, axis=0, bias=True))
# Out:
# Final score (kurtosis):
# [0.4981997]
